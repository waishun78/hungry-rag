# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# Installing the necessary packages
# !pip install accelerate
# !pip install bitsandbytes
# !pip install SentencePiece
# !pip install evaluate
# !pip install bert_score
# !pip install transformers
# !apt install libgraphviz-dev
# !pip install pygraphviz
# Out:
# Collecting accelerate
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.24.1
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.41.2.post2-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.41.2.post2
# Collecting SentencePiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.0 MB/s eta 0:00:00
# Installing collected packages: SentencePiece
# Successfully installed SentencePiece-0.1.99
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.8 MB/s eta 0:00:00
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.23.5)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.2)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Collecting pyarrow-hotfix (from datasets>=2.0.0->evaluate)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.8.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.3.post1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, responses, multiprocess, datasets, evaluate
# Successfully installed datasets-2.15.0 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 pyarrow-hotfix-0.6 responses-0.18.0
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.1.0+cu118)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.5.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.35.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.31.0)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2023.3.post1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.19.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgvc6-plugins-gtk
#   librsvg2-common libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk librsvg2-common libxdot4
# 0 upgraded, 9 newly installed, 0 to remove and 9 not upgraded.
# Need to get 2,433 kB of archives.
# After this operation, 7,694 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2 [125 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2 [2,037 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgail18 amd64 2.24.33-2ubuntu2 [15.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgail-common amd64 2.24.33-2ubuntu2 [132 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxdot4 amd64 2.42.2-6 [16.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgvc6-plugins-gtk amd64 2.42.2-6 [22.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphviz-dev amd64 2.42.2-6 [58.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2 [7,932 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Fetched 2,433 kB in 2s (1,578 kB/s)
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 120880 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../8-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libxdot4:amd64 (2.42.2-6) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.2) ...
# Collecting pygraphviz
#   Downloading pygraphviz-1.11.zip (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.8/120.8 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.11-cp310-cp310-linux_x86_64.whl size=175922 sha256=f81afed2ab0bbe8063822749805aa05bd0ec1ef468a71e37618f16fe8b17e177
#   Stored in directory: /root/.cache/pip/wheels/5b/ee/36/f47a0d35664fbe1a2b5a433ae33c6ad636b00bb231f68a9aaa
# Successfully built pygraphviz
# Installing collected packages: pygraphviz
# Successfully installed pygraphviz-1.11

# %%
# !nvidia-smi
# Out:
# Wed Nov 22 12:18:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Import necessary modules
import os
import torch
import torch.nn as nn
import bitsandbytes as bnb
import accelerate
from transformers import AutoTokenizer, AutoConfig, AutoModelForCausalLM
from transformers import LlamaTokenizer

# %%
load_in_8bit = True
model_name_l = "lmsys/vicuna-7b-v1.5"

model_l = AutoModelForCausalLM.from_pretrained(
    model_name_l,
    torch_dtype=torch.float16,
    load_in_8bit=load_in_8bit,
    device_map="auto"
)
tokenizer_l = LlamaTokenizer.from_pretrained(model_name_l)
# Out:
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/162 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]

# %%
# !pip install git+https://github.com/deepset-ai/haystack.git
# Out:
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-cru9p8nh
#   Running command git clone --filter=blob:none --quiet https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-cru9p8nh
#   Resolved https://github.com/deepset-ai/haystack.git to commit e91f7a8a4db36683e269751411ae9629d130d230
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting boilerpy3 (from farm-haystack==1.23.0rc0)
#   Downloading boilerpy3-1.0.7-py3-none-any.whl (22 kB)
# Collecting events (from farm-haystack==1.23.0rc0)
#   Downloading Events-0.5-py3-none-any.whl (6.8 kB)
# Collecting httpx (from farm-haystack==1.23.0rc0)
#   Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (4.19.2)
# Collecting lazy-imports==0.3.1 (from farm-haystack==1.23.0rc0)
#   Downloading lazy_imports-0.3.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (10.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (3.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (9.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (4.0.0)
# Collecting posthog (from farm-haystack==1.23.0rc0)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Collecting prompthub-py==4.0.0 (from farm-haystack==1.23.0rc0)
#   Downloading prompthub_py-4.0.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (1.10.13)
# Collecting quantulum3 (from farm-haystack==1.23.0rc0)
#   Downloading quantulum3-0.9.0-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 99.9 MB/s eta 0:00:00
# Collecting rank-bm25 (from farm-haystack==1.23.0rc0)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (2.31.0)
# Collecting requests-cache<1.0.0 (from farm-haystack==1.23.0rc0)
#   Downloading requests_cache-0.9.8-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 8.1 MB/s eta 0:00:00
# Collecting scikit-learn>=1.3.0 (from farm-haystack==1.23.0rc0)
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 78.1 MB/s eta 0:00:00
# Collecting sseclient-py (from farm-haystack==1.23.0rc0)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (8.2.3)
# Collecting tiktoken>=0.5.1 (from farm-haystack==1.23.0rc0)
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (4.66.1)
# Requirement already satisfied: transformers==4.35.2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack==1.23.0rc0) (4.35.2)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from prompthub-py==4.0.0->farm-haystack==1.23.0rc0) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack==1.23.0rc0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack==1.23.0rc0) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack==1.23.0rc0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack==1.23.0rc0) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack==1.23.0rc0) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack==1.23.0rc0) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack==1.23.0rc0) (0.4.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2->farm-haystack==1.23.0rc0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack==1.23.0rc0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack==1.23.0rc0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack==1.23.0rc0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack==1.23.0rc0) (2023.7.22)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack==1.23.0rc0) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack==1.23.0rc0) (23.1.0)
# Collecting cattrs>=22.2 (from requests-cache<1.0.0->farm-haystack==1.23.0rc0)
#   Downloading cattrs-23.2.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 9.1 MB/s eta 0:00:00
# Collecting url-normalize>=1.4 (from requests-cache<1.0.0->farm-haystack==1.23.0rc0)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack==1.23.0rc0) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack==1.23.0rc0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack==1.23.0rc0) (3.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->farm-haystack==1.23.0rc0) (3.7.1)
# Collecting httpcore (from httpx->farm-haystack==1.23.0rc0)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->farm-haystack==1.23.0rc0) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack==1.23.0rc0) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack==1.23.0rc0) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack==1.23.0rc0) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack==1.23.0rc0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack==1.23.0rc0) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->farm-haystack==1.23.0rc0) (1.16.0)
# Collecting monotonic>=1.5 (from posthog->farm-haystack==1.23.0rc0)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog->farm-haystack==1.23.0rc0)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from quantulum3->farm-haystack==1.23.0rc0) (7.0.0)
# Collecting num2words (from quantulum3->farm-haystack==1.23.0rc0)
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache<1.0.0->farm-haystack==1.23.0rc0) (1.1.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2->farm-haystack==1.23.0rc0) (2023.6.0)
# Collecting h11<0.15,>=0.13 (from httpcore->httpx->farm-haystack==1.23.0rc0)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# Collecting docopt>=0.6.2 (from num2words->quantulum3->farm-haystack==1.23.0rc0)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: farm-haystack, docopt
#   Building wheel for farm-haystack (pyproject.toml) ... done
#   Created wheel for farm-haystack: filename=farm_haystack-1.23.0rc0-py3-none-any.whl size=886536 sha256=4d0f582997f47a324ec8700c9776a80690cb2a6ca6be63d8fcffc665afde961d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-albgmu19/wheels/e7/f8/df/e7c3a1fea47ea9a9db18c056e698a82658e0fe5814c5608165
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=506549b3129057ab0823b1367612b11250abb15fcc3b7615f685b6721cb42ab9
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built farm-haystack docopt
# Installing collected packages: sseclient-py, monotonic, events, docopt, url-normalize, rank-bm25, num2words, lazy-imports, h11, cattrs, boilerpy3, backoff, tiktoken, scikit-learn, requests-cache, prompthub-py, posthog, httpcore, quantulum3, httpx, farm-haystack
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# Successfully installed backoff-2.2.1 boilerpy3-1.0.7 cattrs-23.2.2 docopt-0.6.2 events-0.5 farm-haystack-1.23.0rc0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.1 lazy-imports-0.3.1 monotonic-1.6 num2words-0.5.13 posthog-3.0.2 prompthub-py-4.0.0 quantulum3-0.9.0 rank-bm25-0.2.2 requests-cache-0.9.8 scikit-learn-1.3.2 sseclient-py-1.8.0 tiktoken-0.5.1 url-normalize-1.4.3

# %%
from haystack.nodes.base import BaseComponent

class Query_Rewriter(BaseComponent):
    outgoing_edges = 1

    def __init__(self, model, tokenizer):
      self.model = model
      self.tokenizer = tokenizer

    def run(self, query: str):

      prompt=f"""Generate some follow up questions I need to better answer your query
                  Example:
                  Question: Where to get Japanese food in Marina Bay Sands that is fine-dining and has a romantic atmosphere at night?
                  Answer:
                  1. What type of Japanese food are you looking for? e.g. sushi, ramen, teppanyaki, etc.
                  2. Do you have a preference for specific dishes or would you like to try a variety of options?
                  3. Are you looking for a specific price range for the food?
                  4. What are you looking for in a romantic atmsphere?
                  5. How late at night are you eating?
                  Question: {query}
                  Answer:"""
      input = self.tokenizer(prompt, return_tensors='pt')
      input_ids = input["input_ids"].to("cuda")
      temperature=0.7
      with torch.no_grad():
        generation_output = self.model.generate(
            input_ids=input_ids,
            temperature=temperature,
            top_p = 1.0,
            do_sample=True,
            return_dict_in_generate=True,
            max_new_tokens=200,
          )

      s = generation_output.sequences[0][len(input_ids[0]):]

      output = self.tokenizer.decode(s)
      return {"query":query, "prompt":prompt, "output":output}, "output_1"

    def run_batch(self, queries):
        # Insert code here to manipulate the input and produce an output dictionary
        output = []
        for query in queries:
            output.append(self.run(query))
        return output, "output_1"

# %%
# Create Custom Query_Rewriter
query_rewriter = Query_Rewriter(model_l, tokenizer_l)

# %%
from haystack.pipelines import Pipeline

# Create a Haystack pipeline
p = Pipeline()
p.add_node(component=query_rewriter, name="QueryRewriter", inputs=["Query"])

# %%
indian_query = "What's some good vegetarian friendly places in Chijmes, Singapore"

# %%
indian_result = p.run(query = indian_query)

# %%
print(f'''
  query: {indian_result["query"]}
  output: {indian_result["output"]}
  ''')
# Out:
#   query: What's some good vegetarian friendly places in Chijmes, Singapore
#   output:
#                   1. Do you have a preference for a specific cuisine or type of restaurant?
#                   2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?
#                   3. Do you have a budget in mind for the meal?
#                   4. Are there any specific dishes or ingredients you're looking for?
#                   5. Is there a time of day you're looking to eat at?</s>

# %%
updated_indian_query = {
    "question":indian_result["query"],
    "clarifier": indian_result["output"],
    "additional_user_criteria":
      """
      1. Vegetarian
      2. Mexican
      3. Cheap
      4. Intimate
      4. Dinner
      """
}

# %%
korean_query = "I want to buy bubble tea and then have Korean fried chicken. Can you give me some suggestions?"

# %%
korean_result = p.run(query = korean_query)

# %%
print(f'''
  query: {korean_result["query"]}
  output: {korean_result["output"]}
  ''')
# Out:
#   query: I want to buy bubble tea and then have Korean fried chicken. Can you give me some suggestions?
#   output:
#                   1. What type of bubble tea are you looking for? e.g. milk tea, fruit tea, etc.
#                   2. Are you looking for a specific type of Korean fried chicken? e.g. soy garlic, spicy, etc.
#                   3. Do you have a preference for a specific brand or type of restaurant?
#                   4. Are you looking for a quick and easy grab-and-go option or a sit-down meal?
#                   5. How close do you want to be to your bubble tea and Korean fried chicken?</s>

# %%
updated_korean_query = {
    "question":korean_result["query"],
    "clarifier": korean_result["output"],
    "additional_user_criteria":
      """
      1. NIL
      2. NIL
      3. NIL
      4. Sit-down
      5. Should be in the same mall
      """
}

# %%
class Annotate_Needs(BaseComponent):
    outgoing_edges = 1

    def __init__(self, model, tokenizer):
      self.model = model
      self.tokenizer = tokenizer

    def run(self, query: dict):
      print(f'Summarizing user needs.... using query:{query}')

      prompt=f"""Generate the user's query requirements annotated with the requirement labels. Here are the categories:
                    Price, Opening, Location, Cuisine, Dietary Restrictions, Ratings, Reservations, Landmark, General (Atmosphere, idea-related needs)

                  Example:
                  Question: Where to get Japanese food in Marina Bay Sands that is fine-dining and has a romantic atmosphere at night?
                  Clarifying Questions:
                  1. What type of Japanese food are you looking for? e.g. sushi, ramen, teppanyaki, etc.
                  2. Do you have a preference for specific dishes or would you like to try a variety of options?
                  3. Are you looking for a specific price range for the food?
                  4. What are you looking for in a romantic atmsphere?
                  5. How late at night are you eating?
                  Additional User Criteria:
                  1. Sushi
                  2. Mostly just sushi
                  3. $$
                  4. Intimate with nice lighting, Inside Marina Bay Sands
                  5. 22:00 minimally
                  Answer:
                  Sushi[Cuisine], $$ [Price], Intimate with nice lighting [General-Atmosphere], Inside Marina Bay Sands [Location], 22:00 minimally [Opening]

                  ________________________________________________________________________________________________________
                  Question: {query["question"]}
                  Clarifying Questions: {query["clarifier"]}
                  Additional User Criteria:{query["additional_user_criteria"]}
                  Answer:"""
      input = self.tokenizer(prompt, return_tensors='pt')
      input_ids = input["input_ids"].to("cuda")
      temperature=0.7
      with torch.no_grad():
        generation_output = self.model.generate(
            input_ids=input_ids,
            temperature=temperature,
            top_p = 1.0,
            do_sample=True,
            return_dict_in_generate=True,
            max_new_tokens=200,
          )

      s = generation_output.sequences[0][len(input_ids[0]):]

      query["requirements"] = self.tokenizer.decode(s)
      return query, "output_1"

    def run_batch(self, queries):
        # Insert code here to manipulate the input and produce an output dictionary
        output = []
        for query in queries:
            output.append(self.run(query))
        return output, "output_1"

# %%
class Search_Term_Generator(BaseComponent):
    outgoing_edges = 1

    def __init__(self, model, tokenizer):
      self.model = model
      self.tokenizer = tokenizer
      # TODO: Might need to change the temperature to be less random and favour more "safe" search terms
      # TODO: Might reduce the max tokens generated as well

    def run(self, query: dict):
      print(f'Generating Search Query.... with query:{query}')
      prompt=f"""Generate the search queries based on the example given below. Here are the categories and increasing importance (1-5), include more important terms more often in queries:
                    Price - 3, Opening - 4, Location - 5, Cuisine - 5, Dietary Restrictions - 5, Ratings - 2, Reservations - 2, Landmark - 2 , General - 1 (Atmosphere, idea-related needs)

                  Example:
                  Question:
                  Where to get Japanese food in Marina Bay Sands that is fine-dining and has a romantic atmosphere at night?
                  Clarifying Questions:
                  1. What type of Japanese food are you looking for? e.g. sushi, ramen, teppanyaki, etc.
                  2. Do you have a preference for specific dishes or would you like to try a variety of options?
                  3. Are you looking for a specific price range for the food?
                  4. What are you looking for in a romantic atmsphere?
                  5. How late at night are you eating?
                  Additional User Input:
                  1. Sushi
                  2. Mostly just sushi
                  3. $$
                  4. Intimate with nice lighting, Inside Marina Bay Sands
                  5. 22:00 minimally
                  Requirements:
                  Sushi[Cuisine], $$ [Price], Intimate with nice lighting [General-Atmosphere], Inside Marina Bay Sands [Location], 22:00 minimally [Opening]
                  Answer:
                  Sushi Restaurant $$ in MBS, Marina Bay Sands Japanese food open till 2200, Romantic Japanese restaurant in Marina Bay Sands, Central Sushi open till late 30-40SGD

                  ________________________________________________________________________________________________________
                  Question:
                  {query["question"]}
                  Clarifying Questions:
                  {query["clarifier"]}
                  Additional User Input:
                  {query["additional_user_criteria"]}
                  Requirements:
                  {query["requirements"]}
                  Answer:
                  """
      input = self.tokenizer(prompt, return_tensors='pt')
      input_ids = input["input_ids"].to("cuda")
      temperature=0.3
      with torch.no_grad():
        generation_output = self.model.generate(
            input_ids=input_ids,
            temperature=temperature,
            top_p = 1.0,
            do_sample=True,
            return_dict_in_generate=True,
            max_new_tokens=100,
          )

      s = generation_output.sequences[0][len(input_ids[0]):]

      query["search_terms"]= self.tokenizer.decode(s)
      return query, "output_1"

    def run_batch(self, queries):
        # Insert code here to manipulate the input and produce an output dictionary
        output = []
        for query in queries:
            output.append(self.run(query))
        return output, "output_1"

# %%
annotater = Annotate_Needs(model_l, tokenizer_l)
search_terms_generator = Search_Term_Generator(model_l, tokenizer_l)

# Create a Haystack pipeline
p2 = Pipeline()
p2.add_node(component=annotater, name="Annotate_Needs", inputs=["Query"])
p2.add_node(component=search_terms_generator, name="Search_Term_Generator", inputs=["Annotate_Needs"])

# %%
result2 = p2.run(query = updated_indian_query)
# Out:
# Summarizing user needs.... using query:{'question': "What's some good vegetarian friendly places in Chijmes, Singapore", 'clarifier': "\n                  1. Do you have a preference for a specific cuisine or type of restaurant?\n                  2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?\n                  3. Do you have a budget in mind for the meal?\n                  4. Are there any specific dishes or ingredients you're looking for?\n                  5. Is there a time of day you're looking to eat at?</s>", 'additional_user_criteria': '\n      1. Vegetarian\n      2. Mexican\n      3. Cheap\n      4. Intimate\n      4. Dinner\n      '}
# Generating Search Query.... with query:{'question': "What's some good vegetarian friendly places in Chijmes, Singapore", 'clarifier': "\n                  1. Do you have a preference for a specific cuisine or type of restaurant?\n                  2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?\n                  3. Do you have a budget in mind for the meal?\n                  4. Are there any specific dishes or ingredients you're looking for?\n                  5. Is there a time of day you're looking to eat at?</s>", 'additional_user_criteria': '\n      1. Vegetarian\n      2. Mexican\n      3. Cheap\n      4. Intimate\n      4. Dinner\n      ', 'requirements': '\n                  Mexican [Cuisine], Cheap [Price], Intimate [General-Atmosphere], Dinner [Opening], Chijmes, Singapore [Location]</s>', 'root_node': 'Query', 'params': {}, 'query': {...}, 'node_id': 'Search_Term_Generator'}

# %%
print(f'''
  query: {result2["query"]}
  clarifier: {result2["clarifier"]}
  additional_user_criteria: {result2["additional_user_criteria"]}
  requirements:{result2["requirements"]}
  search_terms: {result2["search_terms"]}
  ''')
# Out:
#   query: What's some good vegetarian friendly places in Chijmes, Singapore
#   clarifier:
#                   1. Do you have a preference for a specific cuisine or type of restaurant?
#                   2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?
#                   3. Do you have a budget in mind for the meal?
#                   4. Are there any specific dishes or ingredients you're looking for?
#                   5. Is there a time of day you're looking to eat at?</s>
#   additional_user_criteria:
#       1. Vegetarian
#       2. Mexican
#       3. Cheap
#       4. Intimate
#       4. Dinner
#
#   requirements:
#                   Mexican [Cuisine], Cheap [Price], Intimate [General-Atmosphere], Dinner [Opening], Chijmes, Singapore [Location]</s>
#   search_terms:
#                   Mexican Vegetarian Restaurant in Chijmes, Singapore, Cheap Mexican Food in Chijmes, Intimate Mexican Restaurant in Chijmes, Vegetarian Mexican Food in Chijmes, Dinner in Chijmes, Mexican Vegetarian Restaurant in Chijmes, Singapore</s>

# %%
class ParamConstructor(BaseComponent):
  outgoing_edges = 1
  def __init__(self, model, tokenizer):
    self.model = model
    self.tokenizer = tokenizer

  def run(self, query: dict):
    print(f'Generating Params.... with query:{query}')
    prompt=f"""Construct the params based on the example given below. Here are the categories and their descriptions along with increasing importance (1-5), include more important terms more often in params:
                  Location(5): This string indicates the geographic area to be used when searching for restaurants.
                  Term(5): Search term, e.g. food or restaurants. The term may also be the business's name, such as Starbucks.
                  If term is not included the endpoint will default to searching across businesses from a small number of popular categories.
                  Categories(4):Array of strings. Categories to filter the search results with. See the list of supported categories. The category filter can be a list of comma delimited categories.
                  e.g., bars,french will filter by Bars OR French.
                  Price(4):Array of integers. Pricing levels to filter the search result with: 1 = $, 2 = $$, 3 = $$$, 4 = $$$$. The price filter can be a list of comma delimited pricing levels.
                  e.g., 1, 2, 3 will filter the results to show the ones that are $, $$, or $$$.

                  Example:
                  Question:
                  Where to get Japanese food in Marina Bay Sands that is fine-dining and has a romantic atmosphere at night?
                  Clarifying Questions:
                  1. What type of Japanese food are you looking for? e.g. sushi, ramen, teppanyaki, etc.
                  2. Do you have a preference for specific dishes or would you like to try a variety of options?
                  3. Are you looking for a specific price range for the food?
                  4. What are you looking for in a romantic atmsphere?
                  5. How late at night are you eating?
                  Additional User Input:
                  1. Sushi
                  2. Mostly just sushi
                  3. $$
                  4. Intimate with nice lighting, Inside Marina Bay Sands
                  5. 22:00 minimally
                  Requirements:
                  Sushi[Cuisine], $$ [Price], Intimate with nice lighting [General-Atmosphere], Inside Marina Bay Sands [Location], 22:00 minimally [Opening]
                  Search Terms:
                  Sushi Restaurant $$ in MBS, Marina Bay Sands Japanese food open till 2200, Romantic Japanese restaurant in Marina Bay Sands, Central Sushi open till late 30-40SGD
                  Answer:
                  {{
                    "location":"Marina Bay Sands",
                    "term":"Sushi",
                    "price":[2],
                    "categories":"restaurants",
                    "open_now":"true"
                  }}


                  ________________________________________________________________________________________________________
                  Question:
                  {query["question"]}
                  Clarifying Questions:
                  {query["clarifier"]}
                  Additional User Input:
                  {query["additional_user_criteria"]}
                  Requirements:
                  {query["requirements"]}
                  Search Terms:
                  {query["search_terms"]}
                  Answer:
                  """
    input = self.tokenizer(prompt, return_tensors='pt')
    input_ids = input["input_ids"].to("cuda")
    temperature=0.3
    with torch.no_grad():
      generation_output = self.model.generate(
          input_ids=input_ids,
          temperature=temperature,
          top_p = 1.0,
          do_sample=True,
          return_dict_in_generate=True,
          max_new_tokens=100,
        )

    s = generation_output.sequences[0][len(input_ids[0]):]

    output = self.tokenizer.decode(s)
    return {"query":query["question"], "clarifier": query["clarifier"], "additional_user_criteria":query["additional_user_criteria"], "requirements":query["requirements"], "search_terms":query["search_terms"], "params_constructed":output}, "output_1"


  def run_batch(self, queries):
        # Insert code here to manipulate the input and produce an output dictionary
        output = []
        for query in queries:
            output.append(self.run(query))
        return output, "output_1"

# %%
annotater = Annotate_Needs(model_l, tokenizer_l)
search_terms_generator = Search_Term_Generator(model_l, tokenizer_l)
param_constructor = ParamConstructor(model_l, tokenizer_l)

# Create a Haystack pipeline
p5 = Pipeline()
p5.add_node(component=annotater, name="Annotate_Needs", inputs=["Query"])
p5.add_node(component=search_terms_generator, name="Search_Term_Generator", inputs=["Annotate_Needs"])
p5.add_node(component=param_constructor, name="Param_Constructor", inputs=["Search_Term_Generator"])

# %%
result3 = p5.run(query = updated_indian_query)
# Out:
# Summarizing user needs.... using query:{'question': "What's some good vegetarian friendly places in Chijmes, Singapore", 'clarifier': "\n                  1. Do you have a preference for a specific cuisine or type of restaurant?\n                  2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?\n                  3. Do you have a budget in mind for the meal?\n                  4. Are there any specific dishes or ingredients you're looking for?\n                  5. Is there a time of day you're looking to eat at?</s>", 'additional_user_criteria': '\n      1. Vegetarian\n      2. Mexican\n      3. Cheap\n      4. Intimate\n      4. Dinner\n      '}
# Generating Search Query.... with query:{'question': "What's some good vegetarian friendly places in Chijmes, Singapore", 'clarifier': "\n                  1. Do you have a preference for a specific cuisine or type of restaurant?\n                  2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?\n                  3. Do you have a budget in mind for the meal?\n                  4. Are there any specific dishes or ingredients you're looking for?\n                  5. Is there a time of day you're looking to eat at?</s>", 'additional_user_criteria': '\n      1. Vegetarian\n      2. Mexican\n      3. Cheap\n      4. Intimate\n      4. Dinner\n      ', 'requirements': 'Mexican [Cuisine], Cheap [Price], Intimate [Atmosphere], Dinner [Opening], Chijmes, Singapore [Location]</s>', 'root_node': 'Query', 'params': {}, 'query': {...}, 'node_id': 'Search_Term_Generator'}
# Generating Params.... with query:{'question': "What's some good vegetarian friendly places in Chijmes, Singapore", 'clarifier': "\n                  1. Do you have a preference for a specific cuisine or type of restaurant?\n                  2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?\n                  3. Do you have a budget in mind for the meal?\n                  4. Are there any specific dishes or ingredients you're looking for?\n                  5. Is there a time of day you're looking to eat at?</s>", 'additional_user_criteria': '\n      1. Vegetarian\n      2. Mexican\n      3. Cheap\n      4. Intimate\n      4. Dinner\n      ', 'requirements': 'Mexican [Cuisine], Cheap [Price], Intimate [Atmosphere], Dinner [Opening], Chijmes, Singapore [Location]</s>', 'root_node': 'Query', 'params': {}, 'query': {...}, 'node_id': 'Param_Constructor', 'search_terms': '1. Vegetarian Mexican Restaurant in Chijmes, Cheap vegetarian meal in Chijmes, Intimate Mexican restaurant in Chijmes, Vegetarian Mexican food in Chijmes, Dinner in Chijmes Mexican restaurant</s>'}

# %%
print(f'''
  query: {result3["query"]}
  clarifier: {result3["clarifier"]}
  additional_user_criteria: {result3["additional_user_criteria"]}
  requirements:{result3["requirements"]}
  search_terms: {result3["search_terms"]}
  params: {result3["params_constructed"]}
  ''')
# Out:
#   query: What's some good vegetarian friendly places in Chijmes, Singapore
#   clarifier:
#                   1. Do you have a preference for a specific cuisine or type of restaurant?
#                   2. Are you looking for a vegetarian-specific menu or a place that has a good variety of vegetarian options?
#                   3. Do you have a budget in mind for the meal?
#                   4. Are there any specific dishes or ingredients you're looking for?
#                   5. Is there a time of day you're looking to eat at?</s>
#   additional_user_criteria:
#       1. Vegetarian
#       2. Mexican
#       3. Cheap
#       4. Intimate
#       4. Dinner
#
#   requirements:Mexican [Cuisine], Cheap [Price], Intimate [Atmosphere], Dinner [Opening], Chijmes, Singapore [Location]</s>
#   search_terms: 1. Vegetarian Mexican Restaurant in Chijmes, Cheap vegetarian meal in Chijmes, Intimate Mexican restaurant in Chijmes, Vegetarian Mexican food in Chijmes, Dinner in Chijmes Mexican restaurant</s>
#   params:
#                   {
#                     "location":"Chijmes, Singapore",
#                     "term":"Vegetarian",
#                     "price":[1],
#                     "categories":"restaurants",
#                     "open_now":"true"
#                   }</s>

# %%
print(result3["params_constructed"][:-4])
# Out:
#                   {
#                     "location":"Chijmes, Singapore",
#                     "term":"Vegetarian",
#                     "price":[1],
#                     "categories":"restaurants",
#                     "open_now":"true"
#                   }

# %%
import json
param_dict = json.loads(result3["params_constructed"][:-4])
param_dict["limit"] = "20"

# %%
import urllib.parse
import json
import requests
class YelpNode(BaseComponent):
  outgoing_edges = 1
  def __init__(self, api_key, params={}):
    self.api_key = api_key
    self.params = params

  def construct_business_url(self, params: dict) -> str:
    base_url = "https://api.yelp.com/v3/businesses/search?"
    query_parameters = []

    for key, value in params.items():
        # If the value is a list (e.g., for attributes or price levels),
        # we need to add each value separately with the same key.
        if isinstance(value, list):
            for v in value:
                query_parameters.append(f"{key}={urllib.parse.quote(str(v))}")
        else:
            query_parameters.append(f"{key}={urllib.parse.quote(str(value))}")

    # Join all query parameters with "&" and append to the base_url
    url = base_url + "&".join(query_parameters)
    print(url)
    return url

  def get_business_review(self, alias:str):
    #returns the api url for retrieving reviews of businesses
    headers = {"Authorization": f"Bearer {self.api_key}"}

    base_url = "https://api.yelp.com/v3/businesses/{alias}/reviews?limit=20&sort_by=yelp_sort".format(alias=alias)

    response = requests.get(base_url, headers=headers)

    result_json = response.json()
    return result_json

  def run(self, params):
    query_url = self.construct_business_url(params)
    headers = {"Authorization": f"Bearer {self.api_key}"}

    # Assuming you want to search for businesses on Yelp based on the query
    response = requests.get(query_url, headers=headers)

    # Convert the response to JSON
    result_json = response.json()

    # for business in result['businesses']:
    #     business_alias = business['alias']
    #     business['reviews'] = json.load(self.get_business_review(business_alias))

    for items in result_json['businesses']:
      business_alias=items['alias']
      review_json = self.get_business_review(business_alias)
      items['reviews'] = review_json['reviews']

    return {"query": params, "results": result_json},  "yelp_output1"

  def run_batch(self, queries: [dict]):
    # Insert code here to manipulate the input and produce an output dictionary
    output = []
    for query in queries:
        output.append(self.construct_business_url(query))
    return output, "output_1"

# %%
yelp_node = YelpNode("Ew9yemL_AjjazlKSfXGDpbA90j60jI5ZLKwOywepvYJzFCrAtaxHarCp3k18e3tafFq3obqB7sL2vFgrzUCHcJoOvTrqb-h7aUvuhZzgo0-dcyH1bVhhTBC0kQhcZXYx")
yelp_node.run(param_dict)
# Out:
# https://api.yelp.com/v3/businesses/search?location=Chijmes%2C%20Singapore&term=Vegetarian&price=1&categories=restaurants&open_now=true&limit=20
# ({'query': {'location': 'Chijmes, Singapore',
#    'term': 'Vegetarian',
#    'price': [1],
#    'categories': 'restaurants',
#    'open_now': 'true',
#    'limit': '20'},
#   'results': {'businesses': [{'id': 'H7uKG3rAoK3L33HLQaJ1yg',
#      'alias': 'classic-lao-di-fang-vegetarian-singapore',
#      'name': 'Classic Lao Di Fang Vegetarian',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WRBJpWV9B_ICWvxXmEQftQ/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/classic-lao-di-fang-vegetarian-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 2,
#      'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.29793698715023,
#       'longitude': 103.844943344593},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '9 Penang Rd',
#       'address2': '#B1-12 Park Mall',
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '238459',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['9 Penang Rd',
#        '#B1-12 Park Mall',
#        'Singapore 238459',
#        'Singapore']},
#      'phone': '+6565338959',
#      'display_phone': '+65 6533 8959',
#      'distance': 844.0809761016444,
#      'reviews': [{'id': 'JCFW4PoCr9_utdG85-XpTA',
#        'url': 'https://www.yelp.com/biz/classic-lao-di-fang-vegetarian-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=JCFW4PoCr9_utdG85-XpTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "I was invited by a friend to dine at this restaurant. The place wasn't crowded on a Friday night at about 7:30pm but I was told it could be especially when...",
#        'rating': 4,
#        'time_created': '2015-11-20 06:52:10',
#        'user': {'id': 'ya6COrcwApBT3ypUUd0chA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=ya6COrcwApBT3ypUUd0chA',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/2bq2ve51eb-DX8X_fjcqeQ/o.jpg',
#         'name': 'Melvin L.'}},
#       {'id': 'GtNEtfQXJt4EiO_aBvAoJw',
#        'url': 'https://www.yelp.com/biz/classic-lao-di-fang-vegetarian-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=GtNEtfQXJt4EiO_aBvAoJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Food is amazing but the portion is small. For a group of 10, it's better to order 10 dishes (mix of regular and large sizing). Try the Deep fried sweetened...",
#        'rating': 4,
#        'time_created': '2015-12-15 05:53:31',
#        'user': {'id': 'j21GdRmmPI2vzVVxaYpKbg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=j21GdRmmPI2vzVVxaYpKbg',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/PM5Bk5p6-koi-qK2dMvMwA/o.jpg',
#         'name': 'Jorensylv N.'}}]},
#     {'id': 'Rb40xhJlR8X0sTxNjUnBNQ',
#      'alias': 'va-va-voom-cafe-singapore',
#      'name': 'Va Va Voom Cafe',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uk6_XrXpmroLKHxc68tC6Q/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/va-va-voom-cafe-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 2,
#      'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#       {'alias': 'vegetarian', 'title': 'Vegetarian'},
#       {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.2959501, 'longitude': 103.8548279},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '36 Seah Street',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '188392',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['36 Seah Street', 'Singapore 188392', 'Singapore']},
#      'phone': '+6563361248',
#      'display_phone': '+65 6336 1248',
#      'distance': 318.67597244236396,
#      'reviews': [{'id': 'DqOkQIWzavwkawWQi_zo4A',
#        'url': 'https://www.yelp.com/biz/va-va-voom-cafe-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=DqOkQIWzavwkawWQi_zo4A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "I'm a big fan of Vietnamese cuisine and, having lived in northern Vietnam for a while, I can be picky when trying Vietnamese food elsewhere. \n\nVa Va Voom is...",
#        'rating': 3,
#        'time_created': '2012-09-06 05:02:47',
#        'user': {'id': 'OID9ZOyljsyx7HVAP_29aQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=OID9ZOyljsyx7HVAP_29aQ',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/wNpKlX9uvhD0o7-P7sitrQ/o.jpg',
#         'name': 'Ai Lin M.'}},
#       {'id': 'KQyOTuhvsVspGyKg5B0Vkg',
#        'url': 'https://www.yelp.com/biz/va-va-voom-cafe-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=KQyOTuhvsVspGyKg5B0Vkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Been coming here for the past 5 years now and I love it. It has good ambiance, staff are friendly, food is good, cheap, portions are huge. Like seriously,...',
#        'rating': 5,
#        'time_created': '2012-07-31 16:54:39',
#        'user': {'id': '0jmAZwCwQN9ByyWsLx7khA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=0jmAZwCwQN9ByyWsLx7khA',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/ecJyQPetYFEOOCw5iwlyuA/o.jpg',
#         'name': 'Steve A.'}}]},
#     {'id': 'OvAscoJpO3XYIK92bIa4Xw',
#      'alias': 'komala-vilas-restaurant-singapore',
#      'name': 'Komala Vilas Restaurant',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pzuVGIX1t2lwFH4zR0m9zQ/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/komala-vilas-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 74,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'},
#       {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.30642, 'longitude': 103.85192},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '76-78 Serangoon Rd',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '217981',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['76-78 Serangoon Rd',
#        'Singapore 217981',
#        'Singapore']},
#      'phone': '+6562936980',
#      'display_phone': '+65 6293 6980',
#      'distance': 1249.989174640244,
#      'reviews': [{'id': 'Sc5FhYzHuFBsYI89ZC55aQ',
#        'url': 'https://www.yelp.com/biz/komala-vilas-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=Sc5FhYzHuFBsYI89ZC55aQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'We got off at Little India during the Big Bus tour and we were hungry, wile at the Indian temple I asked a few locals and they pointed me here. There was a...',
#        'rating': 4,
#        'time_created': '2023-09-18 21:50:53',
#        'user': {'id': 'YlW-iaOSoWW2CINjCSk8hg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=YlW-iaOSoWW2CINjCSk8hg',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/1xIFHXW61zsuG1JPMKKe1Q/o.jpg',
#         'name': 'Manish B.'}},
#       {'id': 'kl0Fe4cA7_1jgbkrdgG6QA',
#        'url': 'https://www.yelp.com/biz/komala-vilas-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=kl0Fe4cA7_1jgbkrdgG6QA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Komala Vilas is a super popular Vegetarian Indian restaurant in Singapore's Little India.  I came here with two Indian colleagues and trusted them to do all...",
#        'rating': 3,
#        'time_created': '2023-09-13 12:28:54',
#        'user': {'id': 'VHjR5F6mdnLrQcCb0nqCYg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=VHjR5F6mdnLrQcCb0nqCYg',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/E78NiGKeWMYgc101U45QKA/o.jpg',
#         'name': 'Daniel C.'}},
#       {'id': 'gD6GG5pbRh_XdvCduahl5Q',
#        'url': 'https://www.yelp.com/biz/komala-vilas-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=gD6GG5pbRh_XdvCduahl5Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'We enjoyed the friendly service and food here. We ate tomato uttapam, masala dosa and plain dosa. Also, palak paneer. Palak paneer was too good. The paneer...',
#        'rating': 5,
#        'time_created': '2023-08-09 18:36:13',
#        'user': {'id': 'QfEgOUx6s4a5EgvXOxms1Q',
#         'profile_url': 'https://www.yelp.com/user_details?userid=QfEgOUx6s4a5EgvXOxms1Q',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/1-HNJcHL3AbNHN1VRyMdyQ/o.jpg',
#         'name': 'Monica C.'}}]},
#     {'id': 'gzBoOo4E1ornEHYod52uew',
#      'alias': 'papparich-singapore-3',
#      'name': 'PappaRich',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZIY0-XgWRSPxzuKZmaHZ7A/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/papparich-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 10,
#      'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#       {'alias': 'chinese', 'title': 'Chinese'},
#       {'alias': 'indonesian', 'title': 'Indonesian'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.300022, 'longitude': 103.844744},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': 'Plaza Singapura',
#       'address2': '68 Orchard Rd, Blk 01-35',
#       'address3': '',
#       'city': 'Singapore',
#       'zip_code': '238839',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['Plaza Singapura',
#        '68 Orchard Rd, Blk 01-35',
#        'Singapore 238839',
#        'Singapore']},
#      'phone': '+6567359323',
#      'display_phone': '+65 6735 9323',
#      'distance': 969.7659864880051,
#      'reviews': [{'id': 'vbs9Lu9d05LX6CwdPg7Cfw',
#        'url': 'https://www.yelp.com/biz/papparich-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=vbs9Lu9d05LX6CwdPg7Cfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'I heard a lot of good stuff about this place from my friend, especially the Malaysian food. Hmm, I want to say 3.5 stars for service and 4.2 stars for food....',
#        'rating': 4,
#        'time_created': '2017-06-09 21:02:33',
#        'user': {'id': 'YcXxGuOywE67jMh9eKX4rw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=YcXxGuOywE67jMh9eKX4rw',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/3Gu_sM2TJTeofK0r20W8cA/o.jpg',
#         'name': 'David V.'}},
#       {'id': 'RYvcn6k3ve6AC3ySJ7k3jg',
#        'url': 'https://www.yelp.com/biz/papparich-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=RYvcn6k3ve6AC3ySJ7k3jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Never been to this outlet before although I have been to the one at Suntec City.\n\nService here was a little slow today but at least the waitress came around...',
#        'rating': 4,
#        'time_created': '2016-02-21 22:49:01',
#        'user': {'id': 'ij3UcrQUXl7YBoBTcH89rQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=ij3UcrQUXl7YBoBTcH89rQ',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/f6g_rCWQz_GCQabHTiLxVg/o.jpg',
#         'name': 'San-Ju T.'}},
#       {'id': 'ZFvPry9whNcV5hKCgc3SYg',
#        'url': 'https://www.yelp.com/biz/papparich-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=ZFvPry9whNcV5hKCgc3SYg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Came here under a friend's recommendation and I was surprised that the food didn't suck. Sorry, I was half expecting it to be bad since you really cant...",
#        'rating': 4,
#        'time_created': '2015-01-20 10:14:04',
#        'user': {'id': 'bqJNDwrpF-vULjAVAh_LyQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=bqJNDwrpF-vULjAVAh_LyQ',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/85ok9UcLdTkw87AcvQOHxQ/o.jpg',
#         'name': 'Christina N.'}}]},
#     {'id': 'U3i7AaegudvpmDL23_wEmQ',
#      'alias': 'zam-zam-restaurant-singapore',
#      'name': 'Zam Zam Restaurant',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hLBjbtic3SoOcmXkYYxNpg/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/zam-zam-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 98,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'},
#       {'alias': 'halal', 'title': 'Halal'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.30223, 'longitude': 103.85842},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '697-699 North Bridge Rd',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '198676',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['697-699 North Bridge Rd',
#        'Singapore 198676',
#        'Singapore']},
#      'phone': '+6562987011',
#      'display_phone': '+65 6298 7011',
#      'distance': 1054.6575493376265,
#      'reviews': [{'id': 'PF0dSZ3LkTOIRAEIOuOVUQ',
#        'url': 'https://www.yelp.com/biz/zam-zam-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=PF0dSZ3LkTOIRAEIOuOVUQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Came to Zam Zam to try murtabak and it was pretty good! I went with the mutton version and was surprised that I really couldn't taste the gamey flavor,...",
#        'rating': 4,
#        'time_created': '2023-11-14 22:57:33',
#        'user': {'id': 'lSKKtZBmD0GIYbirCMUKtw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=lSKKtZBmD0GIYbirCMUKtw',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/kXvMLnz_WnT4AghkMURzwQ/o.jpg',
#         'name': 'Elaine Y.'}},
#       {'id': 'Hg7c42qJBMZ4zmLhpeeHwg',
#        'url': 'https://www.yelp.com/biz/zam-zam-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=Hg7c42qJBMZ4zmLhpeeHwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Zam Zam is a longstanding Indian restaurant in Little India with plenty of tables on the first and second floor. It's a sit down restaurant with an...",
#        'rating': 5,
#        'time_created': '2023-10-01 16:57:28',
#        'user': {'id': 'GWfALypjNPs_VgAA5GZTuw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=GWfALypjNPs_VgAA5GZTuw',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/JLf8Ed-AiPjFKkVHDNDZNg/o.jpg',
#         'name': 'Helen C.'}},
#       {'id': '5C-PdPvOhSjio0kUAIBx0Q',
#        'url': 'https://www.yelp.com/biz/zam-zam-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=5C-PdPvOhSjio0kUAIBx0Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Their online info said they opened at 7a. We showed up at 8a and the proprietor was rude and said they opened at 9a. We were willing to wait and asked if...',
#        'rating': 3,
#        'time_created': '2023-03-23 12:07:59',
#        'user': {'id': 'Qc4GO8pSQlojzenxG7ZbcA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=Qc4GO8pSQlojzenxG7ZbcA',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/PQa7aKDUv1l19CHHpCGj9g/o.jpg',
#         'name': 'Kyle F.'}}]},
#     {'id': 'aYdHn3OiBekxS3MUXIc59Q',
#      'alias': 'the-soup-spoon-union-singapore',
#      'name': 'The Soup Spoon UNION',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sSoP9qiKdcyVEaI2dgvMmQ/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/the-soup-spoon-union-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 20,
#      'categories': [{'alias': 'salad', 'title': 'Salad'},
#       {'alias': 'soup', 'title': 'Soup'},
#       {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#      'rating': 3.5,
#      'coordinates': {'latitude': 1.29413827390063,
#       'longitude': 103.852946474869},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': 'Raflles City Shopping Centre',
#       'address2': '252 North Bridge Road',
#       'address3': '#B1-61',
#       'city': 'Singapore',
#       'zip_code': '179103',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['Raflles City Shopping Centre',
#        '252 North Bridge Road',
#        '#B1-61',
#        'Singapore 179103',
#        'Singapore']},
#      'phone': '+6563343220',
#      'display_phone': '+65 6334 3220',
#      'distance': 158.91107482903908,
#      'reviews': [{'id': 'E5nx4_VuG_dW0Z3MNS2jRA',
#        'url': 'https://www.yelp.com/biz/the-soup-spoon-union-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=E5nx4_VuG_dW0Z3MNS2jRA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Totally a brilliant idea to have a UNION, combining Soup Broth Asia, The Hand Burger and The Soup Spoon. For the indecisive ones who wants a bit of...',
#        'rating': 4,
#        'time_created': '2015-04-20 06:20:42',
#        'user': {'id': 'O2itSY4F2jnPRXaxdVGOkQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=O2itSY4F2jnPRXaxdVGOkQ',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/KBp6RICM9aGLgkR2n2W7aw/o.jpg',
#         'name': 'Wan Qi T.'}},
#       {'id': 'CBFgnaa2fhPraL2CDyZZ8w',
#        'url': 'https://www.yelp.com/biz/the-soup-spoon-union-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=CBFgnaa2fhPraL2CDyZZ8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'I was looking for the Tim Ho Wan restaurant and realized I made a wrong turn but was too hungry to backtrack so I decided to try this place.  I put my stuff...',
#        'rating': 3,
#        'time_created': '2018-06-24 20:36:12',
#        'user': {'id': 'NaKIUQrZGA9gL7jvq1p0_w',
#         'profile_url': 'https://www.yelp.com/user_details?userid=NaKIUQrZGA9gL7jvq1p0_w',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/qmSMYfVRR0_apKsuDgmWEQ/o.jpg',
#         'name': 'Harun R.'}},
#       {'id': 'llSGt0vNjn1E-_jC7sJ4sg',
#        'url': 'https://www.yelp.com/biz/the-soup-spoon-union-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=llSGt0vNjn1E-_jC7sJ4sg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'It used to be 3 separate eateries (Soup Spoon, Soup Broth Asia and The Handburger), next to each other but they merged it to become The Soup Spoon Union a...',
#        'rating': 3,
#        'time_created': '2015-07-22 18:21:20',
#        'user': {'id': 'Q1oMmm7tKPOzA7_gqcV4zg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=Q1oMmm7tKPOzA7_gqcV4zg',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/fwD-xLU4Fftbqgj63lVMrw/o.jpg',
#         'name': 'Carolyn L.'}}]},
#     {'id': '90zeojRXgvtGNy-Zvz_7Ig',
#      'alias': 'fo-you-yuan-vegetarian-restaurant-singapore',
#      'name': 'Fo You Yuan Vegetarian Restaurant',
#      'image_url': '',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/fo-you-yuan-vegetarian-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 1,
#      'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#       {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#      'rating': 5.0,
#      'coordinates': {'latitude': 1.28944, 'longitude': 103.85},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '310 Lavender St',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '338815',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['310 Lavender St', 'Singapore 338815', 'Singapore']},
#      'phone': '+6567448009',
#      'display_phone': '+65 6744 8009',
#      'distance': 684.3742050024182,
#      'reviews': []},
#     {'id': 'jpQ81mi2KIj_F0S74yreNw',
#      'alias': 'tulasi-vegetarian-and-cafe-singapore',
#      'name': 'Tulasi Vegetarian & Cafe',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fVeOBk651SWvJww-G5dFSQ/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/tulasi-vegetarian-and-cafe-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 4,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'},
#       {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#      'rating': 3.5,
#      'coordinates': {'latitude': 1.30812, 'longitude': 103.8508835},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '46 Race Course Road',
#       'address2': '',
#       'address3': '',
#       'city': 'Singapore',
#       'zip_code': '218559',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['46 Race Course Road',
#        'Singapore 218559',
#        'Singapore']},
#      'phone': '+6562993809',
#      'display_phone': '+65 6299 3809',
#      'distance': 1441.390271042609,
#      'reviews': [{'id': 'Y1thjYXceEvX6nCtMBG31g',
#        'url': 'https://www.yelp.com/biz/tulasi-vegetarian-and-cafe-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=Y1thjYXceEvX6nCtMBG31g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Not too far away from the Little India station lies Tulasi Vegetarian & Cafe. While the menu features cuisine from India, China, Malaysia, Thai and Europe,...',
#        'rating': 4,
#        'time_created': '2014-05-06 23:25:41',
#        'user': {'id': '_PqD0q8FSxMd2f_XleqECw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=_PqD0q8FSxMd2f_XleqECw',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/xa6-wn3t4CjBaSQFpYJmDg/o.jpg',
#         'name': 'Mina O.'}},
#       {'id': 'k35OEiB7885Vuy-RQQi6rA',
#        'url': 'https://www.yelp.com/biz/tulasi-vegetarian-and-cafe-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=k35OEiB7885Vuy-RQQi6rA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Visited this restaurant as I was craving for good briyani (the stuff they serve in Munich and probably the rest of Germany is pathetic). i had selected two...',
#        'rating': 5,
#        'time_created': '2014-08-16 01:37:23',
#        'user': {'id': 'HkoAoEZoJiykUdV_ETW-XA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=HkoAoEZoJiykUdV_ETW-XA',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/F9fYgShIGrq8MCHb922Evg/o.jpg',
#         'name': 'Francoise C.'}},
#       {'id': 'vJUzhSpdW4Z2HmUDtDg-ng',
#        'url': 'https://www.yelp.com/biz/tulasi-vegetarian-and-cafe-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=vJUzhSpdW4Z2HmUDtDg-ng&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'It is very difficult to maintain such a vast menu yet ensuring that customer gets their order timely. I decided to try this restaurant today after reading...',
#        'rating': 3,
#        'time_created': '2017-10-09 18:05:08',
#        'user': {'id': 'i06FhpziFsX6P2YJenRXbA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=i06FhpziFsX6P2YJenRXbA',
#         'image_url': None,
#         'name': 'Varun S.'}}]},
#     {'id': '4PBHeLrPwUftXTjfw5ysew',
#      'alias': 'jai-thai-singapore',
#      'name': 'Jai Thai',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SADXPeEISv1y_SxXO6n5Uw/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/jai-thai-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 21,
#      'categories': [{'alias': 'thai', 'title': 'Thai'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.29627, 'longitude': 103.85532},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '27 Purvis St',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '188604',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['27 Purvis St', 'Singapore 188604', 'Singapore']},
#      'phone': '+6563366908',
#      'display_phone': '+65 6336 6908',
#      'distance': 376.52834348733467,
#      'reviews': [{'id': 'hZJayFF4T6qRNFiGS_0How',
#        'url': 'https://www.yelp.com/biz/jai-thai-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=hZJayFF4T6qRNFiGS_0How&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Friendly service! I missed out on their special combination and they are willing to change my order. I'm so grateful. There's sufficient staff to meet...",
#        'rating': 5,
#        'time_created': '2017-04-17 21:32:14',
#        'user': {'id': 'MmJ-gKRi3hRzBlVqEUEkOg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=MmJ-gKRi3hRzBlVqEUEkOg',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/zIg-U5W9aeQsUhZ9maDmjg/o.jpg',
#         'name': 'Kris A.'}},
#       {'id': 'KEoDPnhKD0Z9TrKlJ-dtEQ',
#        'url': 'https://www.yelp.com/biz/jai-thai-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=KEoDPnhKD0Z9TrKlJ-dtEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "So many different options! As a vegetarian, I'm so glad they had a vegetarian section on the menu. The service is very quick, using ipads at the table, and...",
#        'rating': 4,
#        'time_created': '2020-01-27 16:49:51',
#        'user': {'id': 'KEIzksmYRGhGyk6-IZmwYg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=KEIzksmYRGhGyk6-IZmwYg',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/kdKQwKTLYRK63b8RB9O7uA/o.jpg',
#         'name': 'Akshata R.'}},
#       {'id': 'R0FM89Vl8pyF6WYO8zTmdQ',
#        'url': 'https://www.yelp.com/biz/jai-thai-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=R0FM89Vl8pyF6WYO8zTmdQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "problems that I found: no napkins, not good service. \nThe food was delicious and it's hard to find a good and inexpensive Thai food restaurants Singapore\nwe...",
#        'rating': 4,
#        'time_created': '2019-11-12 03:51:24',
#        'user': {'id': 'cqONDpoQIEqA9kiaEaYAcA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=cqONDpoQIEqA9kiaEaYAcA',
#         'image_url': None,
#         'name': 'Gloria M.'}}]},
#     {'id': 'q_9rMRgldbh9C9OkSw06xA',
#      'alias': 'nalan-cityhall-singapore',
#      'name': 'NALAN CityHall',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MKbUPox54wNkiacNT9_tmQ/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/nalan-cityhall-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 5,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'},
#       {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#      'rating': 3.0,
#      'coordinates': {'latitude': 1.29295858517077,
#       'longitude': 103.851147728818},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '13 Stamford Rd',
#       'address2': '#B2 - 54',
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '178905',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['13 Stamford Rd',
#        '#B2 - 54',
#        'Singapore 178905',
#        'Singapore']},
#      'phone': '+6563366404',
#      'display_phone': '+65 6336 6404',
#      'distance': 273.12179975672615,
#      'reviews': [{'id': 'Kq-lW8TCavGsSgtYVENnfQ',
#        'url': 'https://www.yelp.com/biz/nalan-cityhall-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=Kq-lW8TCavGsSgtYVENnfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Wait staff very nice to lgbt, but also misleads those seeking vegan options that they can make their usual items vegan for you. \nThey can't. They won't....",
#        'rating': 2,
#        'time_created': '2023-09-10 04:20:44',
#        'user': {'id': '4uJgOJrXGfG_UtCJmpHV1A',
#         'profile_url': 'https://www.yelp.com/user_details?userid=4uJgOJrXGfG_UtCJmpHV1A',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/qLGML4SyqRb680xv42nbWw/o.jpg',
#         'name': 'Catrina Daimon L.'}},
#       {'id': 'HR8qREVFFc8KOOm_euG2lw',
#        'url': 'https://www.yelp.com/biz/nalan-cityhall-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=HR8qREVFFc8KOOm_euG2lw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'The restaurant was located just walking distance from the MRT station. For a weekday night, it enjoyed a healthy flow of crowd. The restaurant offered...',
#        'rating': 4,
#        'time_created': '2017-09-18 00:21:28',
#        'user': {'id': '2F38Uc4UNNbFVdyUUnBjOA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=2F38Uc4UNNbFVdyUUnBjOA',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/nkcfSrM1m8BT40IKPO3Gvw/o.jpg',
#         'name': 'Doreen T.'}},
#       {'id': 'wNQpPrO_l_zJse6wvlEzSg',
#        'url': 'https://www.yelp.com/biz/nalan-cityhall-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=wNQpPrO_l_zJse6wvlEzSg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "My brother brought me to this place while I was visiting.  I can't say I'm a pro w dosas but I thought it was OK.  I don't know if this was more authentic...",
#        'rating': 3,
#        'time_created': '2016-07-09 04:54:07',
#        'user': {'id': 'zwmw_cNa5DzJotaFOHTvQg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=zwmw_cNa5DzJotaFOHTvQg',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/XE7isq1BoZuWB_SXdWBhzg/o.jpg',
#         'name': 'Carolyn B.'}}]},
#     {'id': 'UDDq8CLXzfGIz1HM8UandQ',
#      'alias': 'green-on-earth-singapore',
#      'name': 'Green On Earth',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qM0gIKHYWQ9IvHmWoXUTqA/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/green-on-earth-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 3,
#      'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#      'rating': 3.5,
#      'coordinates': {'latitude': 1.3774060706383,
#       'longitude': 103.756951484295},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '2 Phoenix Rd',
#       'address2': '',
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '668156',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['2 Phoenix Rd', 'Singapore 668156', 'Singapore']},
#      'phone': '+6567692230',
#      'display_phone': '+65 6769 2230',
#      'distance': 13971.573149725848,
#      'reviews': [{'id': 'mjwYQHR672Q5gwvzFmZqdw',
#        'url': 'https://www.yelp.com/biz/green-on-earth-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=mjwYQHR672Q5gwvzFmZqdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Parking: Yes, small lot.\n\nThe restaurant is in the corner, it's a completely vegetarian restaurant. They have options of laksa, sichuan noodles, mala hot...",
#        'rating': 5,
#        'time_created': '2017-11-11 16:35:54',
#        'user': {'id': '3QKSFQMslWZSNb-OVYVcSw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=3QKSFQMslWZSNb-OVYVcSw',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/jwWmCKda4Yohfw4FqL6ENA/o.jpg',
#         'name': 'Lisa Y.'}},
#       {'id': 'j9cktXSgquK1LBARRiLOzQ',
#        'url': 'https://www.yelp.com/biz/green-on-earth-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=j9cktXSgquK1LBARRiLOzQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'The staff was quite friendly, but has some difficulty communicating clearly in English. And started preparing the food before we could confirm and pay for...',
#        'rating': 2,
#        'time_created': '2020-11-14 21:09:27',
#        'user': {'id': 'kxrZ09KMv9KUDS7NZe2AZQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=kxrZ09KMv9KUDS7NZe2AZQ',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/qSzqOzs_ix2AJCL5kw82pw/o.jpg',
#         'name': 'S Nitish S.'}},
#       {'id': 'XK2Lqcdxsdsec2NpKuJj6g',
#        'url': 'https://www.yelp.com/biz/green-on-earth-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=XK2Lqcdxsdsec2NpKuJj6g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'We have always passed by this eatery that is located up on the hill but had never been there. Previously before the vegetarian took over, I remembered it...',
#        'rating': 4,
#        'time_created': '2018-02-08 17:00:34',
#        'user': {'id': 'w91OgyE6GjOuZ_MtBk21uw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=w91OgyE6GjOuZ_MtBk21uw',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/6MPEUdN68S7CbOhhi3ZxKA/o.jpg',
#         'name': 'Wenxi C.'}}]},
#     {'id': 'iAaNuCFs5jrJg2t8ISOAfg',
#      'alias': 'the-autobus-singapore',
#      'name': 'The Autobus',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZVETyMx1Mm3TtWbuhe9uvA/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/the-autobus-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 1,
#      'categories': [{'alias': 'themedcafes', 'title': 'Themed Cafes'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.27703, 'longitude': 103.8484},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '6A Shenton Way',
#       'address2': '#01-01',
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '068815',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['6A Shenton Way',
#        '#01-01',
#        'Singapore 068815',
#        'Singapore']},
#      'phone': '+6596907057',
#      'display_phone': '+65 9690 7057',
#      'distance': 1921.0652159018398,
#      'reviews': [{'id': '4wcKcztxhH8DfZwrc7WaPQ',
#        'url': 'https://www.yelp.com/biz/the-autobus-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=4wcKcztxhH8DfZwrc7WaPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Stumbled upon this cafe by accident and had no idea that it recently opened this month! This is a bit of an odd cafe - called "The Autobus" but has lots of...',
#        'rating': 4,
#        'time_created': '2017-07-30 07:45:19',
#        'user': {'id': 'EQ8Kxfmb516BDxG2iIRi2g',
#         'profile_url': 'https://www.yelp.com/user_details?userid=EQ8Kxfmb516BDxG2iIRi2g',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/t4ue9RRgUmGeslcA49rLUg/o.jpg',
#         'name': 'Isabelle M.'}}]},
#     {'id': 'Axy8LsPRd3BsZZA7w7zZkQ',
#      'alias': 'meat-and-green-singapore',
#      'name': 'Meat And Green',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ixIPsJN__90NL_haU4Vc0w/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/meat-and-green-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 9,
#      'categories': [{'alias': 'salad', 'title': 'Salad'},
#       {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#      'rating': 5.0,
#      'coordinates': {'latitude': 1.28663502205538,
#       'longitude': 103.849263042212},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '38 Circular Rd',
#       'address2': '',
#       'address3': '',
#       'city': 'Singapore',
#       'zip_code': '049394',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['38 Circular Rd', 'Singapore 049394', 'Singapore']},
#      'phone': '+6593748449',
#      'display_phone': '+65 9374 8449',
#      'distance': 1006.1265838523678,
#      'reviews': [{'id': 'suIR5KlaldZs_hnEisIZ4A',
#        'url': 'https://www.yelp.com/biz/meat-and-green-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=suIR5KlaldZs_hnEisIZ4A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Healthy, fast, with a sense of humor. What's not to like?\n\nThis is a great takeaway spot if you're looking for something healthy. I wasn't in the mood for...",
#        'rating': 5,
#        'time_created': '2016-03-31 21:42:27',
#        'user': {'id': 'nzIq7_i0C79ToOp-U5e0fA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=nzIq7_i0C79ToOp-U5e0fA',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/wEkP3i0Alw0s78C8EdY57g/o.jpg',
#         'name': 'Michelle M.'}},
#       {'id': '6OUr0f-5hoBPaZAjbO49fg',
#        'url': 'https://www.yelp.com/biz/meat-and-green-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=6OUr0f-5hoBPaZAjbO49fg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "I LOVE THIS PLACE SO MUCH!\n\nIf i dont come here for awhile, i start missing the remdang beef salad. I can't describe why it's so good. It just is. The fresh...",
#        'rating': 5,
#        'time_created': '2016-10-03 04:24:31',
#        'user': {'id': 'WjFI4zVmeDkA7c3tcOy3-g',
#         'profile_url': 'https://www.yelp.com/user_details?userid=WjFI4zVmeDkA7c3tcOy3-g',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/XONSOKTUVpAosI3kCDsmLA/o.jpg',
#         'name': 'Melissa H.'}},
#       {'id': 'RTf60xpmgToV_3JzLG4GIQ',
#        'url': 'https://www.yelp.com/biz/meat-and-green-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=RTf60xpmgToV_3JzLG4GIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Lock me up and throw away the key!\n\nDining here turned my colleague and I into petty criminals. So engrossed were we in our lunchtime rant-a-thon that we...',
#        'rating': 5,
#        'time_created': '2017-02-09 08:50:06',
#        'user': {'id': 'YziRZOh5MrqN5b84dQ9AIQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=YziRZOh5MrqN5b84dQ9AIQ',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/z9T19wxmS8cpyCrXdiPs7w/o.jpg',
#         'name': 'Dan P.'}}]},
#     {'id': '9WoGl5Y9Wr4FsgVsNuTb-g',
#      'alias': 'house-of-rice-roll-and-porridge-singapore',
#      'name': 'House of Rice Roll and Porridge',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/47oLTYcpvr_WqMxY_XU9-A/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/house-of-rice-roll-and-porridge-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 11,
#      'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#      'rating': 3.5,
#      'coordinates': {'latitude': 1.29847, 'longitude': 103.8390732},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '89 Killiney Rd',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '239529',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['89 Killiney Rd', 'Singapore 239529', 'Singapore']},
#      'phone': '+6567361355',
#      'display_phone': '+65 6736 1355',
#      'distance': 1476.17038029974,
#      'reviews': [{'id': 'mZweY6BO_tkhcAc1iXFBTA',
#        'url': 'https://www.yelp.com/biz/house-of-rice-roll-and-porridge-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=mZweY6BO_tkhcAc1iXFBTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Great place to get your comfort congee or porridge as they say. They have a great selection with meat, seafood or vegetarian options. They also have the...',
#        'rating': 4,
#        'time_created': '2016-11-20 06:24:45',
#        'user': {'id': 'BVR-13IJTN29ivKmW8psPA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=BVR-13IJTN29ivKmW8psPA',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/jaSLKSoz-NbsOq0z6KuoHg/o.jpg',
#         'name': 'Charlie L.'}},
#       {'id': 'ZJXJBm8llYfaY3Z81Tu7IQ',
#        'url': 'https://www.yelp.com/biz/house-of-rice-roll-and-porridge-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=ZJXJBm8llYfaY3Z81Tu7IQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'I stopped by on a weekday lunchtime for some prawn rice rolls, and it was about $5 ish. \n\nI was aghast by the size (or lack of size) of their prawns. Tiny,...',
#        'rating': 2,
#        'time_created': '2015-10-22 05:47:50',
#        'user': {'id': 'SBVNVima7JWeA-6TXVvJbw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=SBVNVima7JWeA-6TXVvJbw',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/wpM5IU5eSnTJWvMZaKlAFA/o.jpg',
#         'name': 'Natalie H.'}},
#       {'id': 'KFrY46MfEwHpL3I2lkmCYA',
#        'url': 'https://www.yelp.com/biz/house-of-rice-roll-and-porridge-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=KFrY46MfEwHpL3I2lkmCYA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "I've been here for lunch once and was with my boss's so didn't really concentrate too much in the food. \n\nThe gf was craving Chee Cheong Fun and I suddenly...",
#        'rating': 4,
#        'time_created': '2015-01-03 19:49:27',
#        'user': {'id': 'oGtf2Wbi2Wq6TTJecDZFMQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=oGtf2Wbi2Wq6TTJecDZFMQ',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/u9rvUXlNujpVRC8bb6Arig/o.jpg',
#         'name': 'Jason L.'}}]},
#     {'id': 'pdjGMDiITalYh32BHvcwZg',
#      'alias': 'usman-restaurant-singapore',
#      'name': 'Usman Restaurant',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kipDT2aMBSSZky7tAjubtA/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/usman-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 38,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.3096699, 'longitude': 103.85401},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '238 Serangoon Rd',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '218085',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['238 Serangoon Rd',
#        'Singapore 218085',
#        'Singapore']},
#      'phone': '+6562968949',
#      'display_phone': '+65 6296 8949',
#      'distance': 1618.7095687344981,
#      'reviews': [{'id': '9KvU4XgVw6YHiq7-wBO1Dg',
#        'url': 'https://www.yelp.com/biz/usman-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=9KvU4XgVw6YHiq7-wBO1Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "I've been treated to a lot of Indian places at home in Australia, but never have I tasted such amazing flavours.\n\nUsman's concerned me when I first...",
#        'rating': 5,
#        'time_created': '2015-10-31 00:26:36',
#        'user': {'id': 'zS9tLFnLX5oGj_x7eNLcPA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=zS9tLFnLX5oGj_x7eNLcPA',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/cxLcYRgXzCb0sdlFmdC_oQ/o.jpg',
#         'name': 'Russell B.'}},
#       {'id': 'PUgzJwZPVIc32wzTExFlpg',
#        'url': 'https://www.yelp.com/biz/usman-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=PUgzJwZPVIc32wzTExFlpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Daal Keema fry & pala paneer were good\n\nMix tandoor sizzler has no prawns though it's listed under prawns in the menu. It had a great smoky flavour even...",
#        'rating': 4,
#        'time_created': '2022-07-29 20:58:58',
#        'user': {'id': 'fBL9s_Cym7VJ3AY7Ioeaqw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=fBL9s_Cym7VJ3AY7Ioeaqw',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/wk0ytvTZN98dwDZ5onaMDg/o.jpg',
#         'name': 'Gabriel S.'}},
#       {'id': 'I0d4huYOAH_eAUvuu1jVSA',
#        'url': 'https://www.yelp.com/biz/usman-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=I0d4huYOAH_eAUvuu1jVSA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Very good Pakistani restaurant. I ate chicken tandoori taste was very good & delicious. But they don't even No their restaurant is listed in yelp lol ....",
#        'rating': 5,
#        'time_created': '2023-05-19 18:28:25',
#        'user': {'id': 'ejcWL2Nv8J7gjqtJTLENBw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=ejcWL2Nv8J7gjqtJTLENBw',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/oUKNMtuJrz64ETfN7gz3hg/o.jpg',
#         'name': 'Arif R.'}}]},
#     {'id': 'i3p4I0esdmWwbXjIjkgQMQ',
#      'alias': 'murugan-idli-shop-singapore',
#      'name': 'Murugan Idli Shop',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ySccTLZGAglKQNnnDmGlCA/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/murugan-idli-shop-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 27,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'},
#       {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.30892, 'longitude': 103.85606},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '81 Syed Alwi Rd',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '207660',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['81 Syed Alwi Rd', 'Singapore 207660', 'Singapore']},
#      'phone': '+6562980858',
#      'display_phone': '+65 6298 0858',
#      'distance': 1598.718203815303,
#      'reviews': [{'id': '_zF05AqLGzfZ-vfrSN7QDA',
#        'url': 'https://www.yelp.com/biz/murugan-idli-shop-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=_zF05AqLGzfZ-vfrSN7QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Idlis are fluffy south indian rice cakes. The process for making them is simple - you prepare a batter made of grounded rice and lentils, leave the batter...',
#        'rating': 5,
#        'time_created': '2015-01-02 09:14:25',
#        'user': {'id': 'A-ac-5NVNQ94jQ8jn63BVA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=A-ac-5NVNQ94jQ8jn63BVA',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/jyhY__4xfEppraaOMKmT1Q/o.jpg',
#         'name': 'Srivatsan S.'}},
#       {'id': 'WIKfHXP57Sik7-zIwPti_Q',
#        'url': 'https://www.yelp.com/biz/murugan-idli-shop-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=WIKfHXP57Sik7-zIwPti_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': '4.5 stars. This place is a gem! Totally worth the 2000+ reviews. I wanted good south Indian food and we decided to come here based on the reviews. \n\nThe...',
#        'rating': 4,
#        'time_created': '2022-09-07 17:20:42',
#        'user': {'id': 'V56ven0rPypaIW30HYzy6g',
#         'profile_url': 'https://www.yelp.com/user_details?userid=V56ven0rPypaIW30HYzy6g',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/ZEs02x3miJE575g4Wpqx6w/o.jpg',
#         'name': 'Pranjali S.'}},
#       {'id': 'MpTFBHZ8nbv-pvzH2kevag',
#        'url': 'https://www.yelp.com/biz/murugan-idli-shop-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=MpTFBHZ8nbv-pvzH2kevag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Great place, good food quick service and affordable prices. One of those weekend retreats when there are no other bright ideas.',
#        'rating': 4,
#        'time_created': '2020-11-14 18:51:44',
#        'user': {'id': 'kxrZ09KMv9KUDS7NZe2AZQ',
#         'profile_url': 'https://www.yelp.com/user_details?userid=kxrZ09KMv9KUDS7NZe2AZQ',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/qSzqOzs_ix2AJCL5kw82pw/o.jpg',
#         'name': 'S Nitish S.'}}]},
#     {'id': 'QF1gXf_lvMSf57ed7vr6hg',
#      'alias': 'ananda-bhavan-singapore-4',
#      'name': 'Ananda Bhavan',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xRnmUbecKhtr7pXDP2uglw/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/ananda-bhavan-singapore-4?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 9,
#      'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#       {'alias': 'indpak', 'title': 'Indian'}],
#      'rating': 2.5,
#      'coordinates': {'latitude': 1.30955, 'longitude': 103.85545},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '95 Syed Alwi Rd',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '207671',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['95 Syed Alwi Rd', 'Singapore 207671', 'Singapore']},
#      'phone': '+6563980837',
#      'display_phone': '+65 6398 0837',
#      'distance': 1633.4011041073588,
#      'reviews': [{'id': 'Lb02sEnTLYkgAncrgt7wvg',
#        'url': 'https://www.yelp.com/biz/ananda-bhavan-singapore-4?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=Lb02sEnTLYkgAncrgt7wvg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Indian restaurant most of folks are Indian eat there. The restaurant  has friendly staff's who are kind and pleasant. But the foods sold  are expensive it's...",
#        'rating': 4,
#        'time_created': '2022-10-05 23:35:52',
#        'user': {'id': 'ejcWL2Nv8J7gjqtJTLENBw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=ejcWL2Nv8J7gjqtJTLENBw',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/oUKNMtuJrz64ETfN7gz3hg/o.jpg',
#         'name': 'Arif R.'}},
#       {'id': 'TiWifhBMQzp22dpvDyBxwg',
#        'url': 'https://www.yelp.com/biz/ananda-bhavan-singapore-4?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=TiWifhBMQzp22dpvDyBxwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Given the quantity and quality of vegetarian restaurants in Little India, I would go to Ananda Bhavan only if I'm left with no other choice. Oddly enough,...",
#        'rating': 3,
#        'time_created': '2015-01-02 09:43:20',
#        'user': {'id': 'A-ac-5NVNQ94jQ8jn63BVA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=A-ac-5NVNQ94jQ8jn63BVA',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/jyhY__4xfEppraaOMKmT1Q/o.jpg',
#         'name': 'Srivatsan S.'}},
#       {'id': 'FsH62SVR-1HSjYbLAl43Gw',
#        'url': 'https://www.yelp.com/biz/ananda-bhavan-singapore-4?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=FsH62SVR-1HSjYbLAl43Gw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Cheap, fast, vegetarian. But enough about me! (HEYOOOH)\nHonestly, it's some good stuff conveniently located across from Mustafa, assuming you can find a...",
#        'rating': 4,
#        'time_created': '2016-08-24 10:45:36',
#        'user': {'id': 'Hz7X2SWyDMTQTaV6PBkcdg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=Hz7X2SWyDMTQTaV6PBkcdg',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/CwyK2H2dFZFBBNkNNPQRlQ/o.jpg',
#         'name': 'El P.'}}]},
#     {'id': 'IafzX6NX3CrPc0wNRuamNw',
#      'alias': 'madras-new-woodlands-singapore',
#      'name': 'Madras New Woodlands',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w_WwN51PVDAS4OLmefJAtg/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/madras-new-woodlands-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 10,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#      'rating': 3.5,
#      'coordinates': {'latitude': 1.3052, 'longitude': 103.8544998},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '10 Upper Dickson Road',
#       'address2': None,
#       'address3': None,
#       'city': 'Singapore',
#       'zip_code': '207470',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['10 Upper Dickson Road',
#        'Singapore 207470',
#        'Singapore']},
#      'phone': '',
#      'display_phone': '',
#      'distance': 1244.0150385218697,
#      'reviews': [{'id': 'Y4AZMwCWjz5GfSzGu_sAKQ',
#        'url': 'https://www.yelp.com/biz/madras-new-woodlands-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=Y4AZMwCWjz5GfSzGu_sAKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'I have no idea what we ordered but it was all amazing! Apparently the appam is very authentic.  The only downside was that as a business traveler I wish we...',
#        'rating': 4,
#        'time_created': '2022-02-28 05:19:25',
#        'user': {'id': 'h5F-iIlkETUNZNW6b_Xriw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=h5F-iIlkETUNZNW6b_Xriw',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/lq5wYP--UYHHEMLSo5NM9A/o.jpg',
#         'name': 'Tiffany P.'}},
#       {'id': 'huVvvw7xjiH8Ev-tGF-DjA',
#        'url': 'https://www.yelp.com/biz/madras-new-woodlands-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=huVvvw7xjiH8Ev-tGF-DjA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'We came here for its so called famous "fresh goat milk" coffee. However, it wasn\'t that great and it didn\'t taste that great. In addition, the waiter served...',
#        'rating': 2,
#        'time_created': '2018-10-21 13:30:32',
#        'user': {'id': 'zrnVqJMsN-2PFfxn0zBkyw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=zrnVqJMsN-2PFfxn0zBkyw',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/YNPt-vTZbFw2Ehp4_2iIXw/o.jpg',
#         'name': 'Victor H.'}},
#       {'id': 'difUGOICo8oRlovhgmNGqA',
#        'url': 'https://www.yelp.com/biz/madras-new-woodlands-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=difUGOICo8oRlovhgmNGqA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Met my ex-school mates at this Indian Dosa restaurant in little India section of Singapore. It was good to see them there and it was a good time to catch up...',
#        'rating': 4,
#        'time_created': '2017-09-07 21:44:19',
#        'user': {'id': 'NaKIUQrZGA9gL7jvq1p0_w',
#         'profile_url': 'https://www.yelp.com/user_details?userid=NaKIUQrZGA9gL7jvq1p0_w',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/qmSMYfVRR0_apKsuDgmWEQ/o.jpg',
#         'name': 'Harun R.'}}]},
#     {'id': 'rrDzAqHIHjjH19MZBgO2RA',
#      'alias': 'saravanabhavan-restaurant-singapore',
#      'name': 'Saravanabhavan Restaurant',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7EnSSslxHxHGCFX2SfGcng/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/saravanabhavan-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 9,
#      'categories': [{'alias': 'indpak', 'title': 'Indian'},
#       {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#      'rating': 2.5,
#      'coordinates': {'latitude': 1.30912, 'longitude': 103.85585},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '84, Syed Alwi Rd',
#       'address2': None,
#       'address3': '',
#       'city': 'Singapore',
#       'zip_code': '207663',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['84, Syed Alwi Rd',
#        'Singapore 207663',
#        'Singapore']},
#      'phone': '+6562970770',
#      'display_phone': '+65 6297 0770',
#      'distance': 1600.5434498210732,
#      'reviews': [{'id': 'VU5pynW9Bvo0cMjzvuPLvQ',
#        'url': 'https://www.yelp.com/biz/saravanabhavan-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=VU5pynW9Bvo0cMjzvuPLvQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Very good vegetarian Indian food.    Had saravana special and masala dosa.  Very tasty, good portion size and attentive/friendly staff.    Just a Ross the...',
#        'rating': 5,
#        'time_created': '2019-06-05 00:57:46',
#        'user': {'id': '5ceKqAAOe1b6R2pvpMym8A',
#         'profile_url': 'https://www.yelp.com/user_details?userid=5ceKqAAOe1b6R2pvpMym8A',
#         'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/80d6ZhkPox9xuAQjOCXGnA/o.jpg',
#         'name': 'Momo L.'}},
#       {'id': 'z8qop5GvujUw_8NM9z_r3A',
#        'url': 'https://www.yelp.com/biz/saravanabhavan-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=z8qop5GvujUw_8NM9z_r3A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'I guess the food price is ok. The taste of the food is average, not awesome. Menu is not very friendly for people who are unfamiliar with Indian cuisine as...',
#        'rating': 3,
#        'time_created': '2017-11-28 17:30:53',
#        'user': {'id': 'nbYBWghA9fWHz-0JokGotA',
#         'profile_url': 'https://www.yelp.com/user_details?userid=nbYBWghA9fWHz-0JokGotA',
#         'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/VF71IZXsNfsjOrsQxRwZHg/o.jpg',
#         'name': 'Ally T.'}},
#       {'id': 'OhALAkdX3aWeyiClu805gw',
#        'url': 'https://www.yelp.com/biz/saravanabhavan-restaurant-singapore?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=OhALAkdX3aWeyiClu805gw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Chennai's most famous export, Saravana Bhavan has many branches all over the world -- including several in Singapore. It's at its natural best in the only...",
#        'rating': 4,
#        'time_created': '2012-08-29 16:15:50',
#        'user': {'id': 'Ml61UOrHtdUCwW0JcTM_Vg',
#         'profile_url': 'https://www.yelp.com/user_details?userid=Ml61UOrHtdUCwW0JcTM_Vg',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/aq3rWPG03qAueaL5_jfbFw/o.jpg',
#         'name': 'Adrianna T.'}}]},
#     {'id': '2tGFUtUrE0DhwlX59pbArA',
#      'alias': '328-katong-laksa-singapore-3',
#      'name': '328 Katong Laksa',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eOsefga8soQKnxJOUpbOsg/o.jpg',
#      'is_closed': False,
#      'url': 'https://www.yelp.com/biz/328-katong-laksa-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#      'review_count': 93,
#      'categories': [{'alias': 'singaporean', 'title': 'Singaporean'}],
#      'rating': 4.0,
#      'coordinates': {'latitude': 1.3051, 'longitude': 103.90318},
#      'transactions': [],
#      'price': '$',
#      'location': {'address1': '51 East Coast Rd',
#       'address2': '',
#       'address3': '',
#       'city': 'Singapore',
#       'zip_code': '428770',
#       'country': 'SG',
#       'state': 'SG',
#       'display_address': ['51 East Coast Rd',
#        'Singapore 428770',
#        'Singapore']},
#      'phone': '+6597328163',
#      'display_phone': '+65 9732 8163',
#      'distance': 5793.694867715855,
#      'reviews': [{'id': 'gxJwuoyuUV4xxIxm8Kvqfw',
#        'url': 'https://www.yelp.com/biz/328-katong-laksa-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=gxJwuoyuUV4xxIxm8Kvqfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Good Laksa, highly recommended.\nFlavourful thick gravy with daun kosom.\nNot enough cockles, it would enhance the dish.',
#        'rating': 5,
#        'time_created': '2023-04-22 17:38:21',
#        'user': {'id': 'CeexoKHt95Km6jCSQs50Gw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=CeexoKHt95Km6jCSQs50Gw',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/5SCl-5koSrHUHsg4Y9hJRw/o.jpg',
#         'name': 'Chris T.'}},
#       {'id': '4yr919PJZcAKLPQNMII-Lw',
#        'url': 'https://www.yelp.com/biz/328-katong-laksa-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=4yr919PJZcAKLPQNMII-Lw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': 'Our hotel recommended 328 Katong Laksa as a place to get laksa so when we stumbled upon it, we tried it out. I had my husband sit at a table outside while I...',
#        'rating': 3,
#        'time_created': '2023-10-09 08:09:03',
#        'user': {'id': '_pBzBgtCTN9PNUPfgPDI8A',
#         'profile_url': 'https://www.yelp.com/user_details?userid=_pBzBgtCTN9PNUPfgPDI8A',
#         'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/hf5_r3w-4RULlMbVpdiH8w/o.jpg',
#         'name': 'Trina D.'}},
#       {'id': 'HIcLQMgXQJugtrmfP-PrYg',
#        'url': 'https://www.yelp.com/biz/328-katong-laksa-singapore-3?adjust_creative=P2E-4WvnsgTHDYWehmwoCA&hrid=HIcLQMgXQJugtrmfP-PrYg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=P2E-4WvnsgTHDYWehmwoCA',
#        'text': "Probably the most annoying place I've been to. They won't let us move any of the chairs and tables to accommodate our larger party. The laksa is not...",
#        'rating': 1,
#        'time_created': '2023-03-28 19:10:50',
#        'user': {'id': 'zNaZhUgxr_qrWV3uIRL7Fw',
#         'profile_url': 'https://www.yelp.com/user_details?userid=zNaZhUgxr_qrWV3uIRL7Fw',
#         'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/vTlPvWSKLbns-TxYHexc4Q/o.jpg',
#         'name': 'Jenny C.'}}]}],
#    'total': 31,
#    'region': {'center': {'longitude': 103.85204315185547,
#      'latitude': 1.2952458917403575}}}},
#  'yelp_output1')

# %% [markdown]
# ## Archive

# %%
from haystack import BaseComponent

class CustomNodeA(BaseComponent):
    outgoing_edges = 1

    def run(self, query: dict):
        # Append some text to the input
        print("A",query)
        query["text"] += " processed by NodeA"
        return query, "output_1"

    def run_batch(self, queries: list):
        # Insert code here to manipulate the input and produce an output dictionary
        input_data = []
        for query in queries:
            input_data.append(self.run(query))
        return input_data, "output_1"

class CustomNodeB(BaseComponent):
    outgoing_edges = 1

    def run(self, query: dict):
        # Append some more te
        print("B", query)
        query["text"] += " and then by NodeB"
        return query, "output_1"
    def run_batch(self, queries: list):
        # Insert code here to manipulate the input and produce an output dictionary
        output_2 = []
        for query in queries:
            output_2.append(self.run(query))
        return output_2, "output_1"

class NodeC(BaseComponent):
    outgoing_edges = 1
    def run(self, query:dict):
      print("C", query)
      query["hi"] = "hi"
      return query, "output_1"
    def run_batch(self, queries:list):
      return queries,"output_1"

# %%
from haystack import Pipeline

# Create instances of your custom nodes
node_a = CustomNodeA()
node_b = CustomNodeB()
node_c = NodeC()

# Create a Haystack pipeline and add the nodes
pipeline = Pipeline()
pipeline.add_node(component=node_a, name="NodeA", inputs=["Query"])
pipeline.add_node(component=node_b, name="NodeB", inputs=["NodeA"])
pipeline.add_node(component=node_c, name="NodeC", inputs=["NodeB"])

# %%
pipeline.draw("pipeline_retrieval.png")

# %%
# Prepare initial input and run the pipeline
initial_input= {"text": "Start"}
output = pipeline.run(query=initial_input)

print(output)
# Out:
# A {'text': 'Start'}
# B {'text': 'Start processed by NodeA', 'root_node': 'Query', 'params': {}, 'query': {...}, 'node_id': 'NodeB'}
# C {'text': 'Start processed by NodeA and then by NodeB', 'root_node': 'Query', 'params': {}, 'query': {...}, 'node_id': 'NodeC'}
# {'text': 'Start processed by NodeA and then by NodeB', 'root_node': 'Query', 'params': {}, 'query': {...}, 'node_id': 'NodeC', 'hi': 'hi'}
